# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage,AIMessage,SystemMessage


import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

stress_level=2
features={"anxiety_level":5,
        "carrer_tension":9,
        "bulling":2,
        "self_esteem":5,
        "confidence":3
          }

info_prompt=ChatPromptTemplate(
[
        SystemMessage
        (
            content=
            f"""->You are an helpful and empathetic mental wellness assistance.\n
            ->Your goal is to provide supportive, actionable advice and tasks which are performable based on a person's stress level.\n
            ->There are 3 progessive stress levels:
                1 = Small or Minor stress caused by burnout, fatigue, etc.(No need of doctor consultance).\n
                2 = Medium or Mediocar level stress(recommend going for doctor consultance).\n
                3 = Sever and Large level stress(Strongly recommend doctor consultance).\n
            ->On this stress level you have to give soltuions such as mental exercises, breathing exercises etc.To help and support the person in stress and to remove his/her stress.Dont forget to recommend the doctor consultancy when required.\n
            ->Provide suggestion in task format example:cycling,exercising,breathing exercises.In clear, number list on given stress level only.Keep your tone warm and encouraging.\n
            ->Give the soltion in json or dict format first the main body and then the 9 to 15 solutions and there descriptive name.\n
              example: "main body": "Here some descriptiona and humble text to help the person in stress",
                       "solutions": "1(only number value)":"description of solution 1",
                                     "2":"description of solution 2",
                                     "3":"description of solution 3",
                                     "4":"description of solution 4",
                                     "5":"description of solution 5",
                                     "6":"description of solution 6",
                                     "7":"description of solution 7",
                                     "8":"description of solution 8",
                                     "9":"description of solution 9",
                                     "10":"description of solution 10"
                                     "11":"description of solution 11",
                                     "12":"description of solution 12"
                                     "13":"description of solution 13",
                                     "14":"description of solution 14",
                                     "15":"description of solution 15"
            ->Make sure the solutions are actionable and easy to follow.\n

            ->Dont suggest data in any other format except json or dict.\n
            ->output should start with json or dict only dont specify it that its json or dict format example '''json/dict dont do it.\n
            """
        ),
        HumanMessage(
            content=f"""The stress level of patient={stress_level}.\n
            Here are some input that describe patient well{features}.\n
            Use this features and give suggetions on this conditions.
            Suggest the solutions to the patients on the given stress level only.\n
            """
        )
    ]
)


llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.6,
    google_api_key=api_key
)

final_prompt=info_prompt.invoke({"stress_level":stress_level})

# print(final_prompt)

response=llm.invoke(final_prompt)

print(response.content)
# Out:
# ```json
# {
#   "main body": "It sounds like you're carrying a significant load right now, especially with the high career tension, and it's completely understandable to feel the effects on your anxiety, self-esteem, and confidence. Please know that it's a sign of strength to acknowledge these feelings. For the level of stress you're experiencing, it's highly recommended to consult with a doctor or a mental health professional. They can provide personalized guidance and support to help you navigate these challenges effectively. In the meantime, here are some supportive tasks you can try to help manage your stress, anxiety, and build your confidence, working alongside any professional advice you receive.",
#   "solutions": {
#     "1": "Deep Diaphragmatic Breathing: Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.",
#     "2": "Progressive Muscle Relaxation (PMR): Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.",
#     "3": "Mindful Walking: Take a 15-20 minute walk outdoors. Pay close attention to your senses: the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.",
#     "4": "Journaling for Career Worries: Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.",
#     "5": "Identify and Affirm Strengths: Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.",
#     "6": "Set Small, Achievable Goals: Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.",
#     "7": "Positive Self-Talk Practice: Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'",
#     "8": "Gratitude Practice: Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook.",
#     "9": "Time Management Technique (e.g., Pomodoro): Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.",
#     "10": "Mindful Body Scan: Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.",
#     "11": "Listen to Calming Music or Nature Sounds: Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.",
#     "12": "Engage in a Hobby or Creative Activity: Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment.",
#     "13": "Connect with a Trusted Person: Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load.",
#     "14": "Gentle Stretching or Yoga: Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.",
#     "15": "Limit Exposure to Stress Triggers: If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks."
#   }
# }
# ```

# %%
temp=response.content

# %%
solution=dict()

# %%
for i in range(len(temp)):
    if temp[i]=='{':
        keep_start=i
        break

# %%
keep_start
# Out:
# 8

# %%
for i in range(len(temp)):
    if temp[i]=='}':
        keep_end=i+3
        break

# %%
keep_end
# Out:
# 4674

# %%
temp=temp[keep_start:keep_end]

# %%
print(temp)
# Out:
# {
#   "main body": "It sounds like you're carrying a significant load right now, especially with the high career tension, and it's completely understandable to feel the effects on your anxiety, self-esteem, and confidence. Please know that it's a sign of strength to acknowledge these feelings. For the level of stress you're experiencing, it's highly recommended to consult with a doctor or a mental health professional. They can provide personalized guidance and support to help you navigate these challenges effectively. In the meantime, here are some supportive tasks you can try to help manage your stress, anxiety, and build your confidence, working alongside any professional advice you receive.",
#   "solutions": {
#     "1": "Deep Diaphragmatic Breathing: Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.",
#     "2": "Progressive Muscle Relaxation (PMR): Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.",
#     "3": "Mindful Walking: Take a 15-20 minute walk outdoors. Pay close attention to your senses: the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.",
#     "4": "Journaling for Career Worries: Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.",
#     "5": "Identify and Affirm Strengths: Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.",
#     "6": "Set Small, Achievable Goals: Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.",
#     "7": "Positive Self-Talk Practice: Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'",
#     "8": "Gratitude Practice: Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook.",
#     "9": "Time Management Technique (e.g., Pomodoro): Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.",
#     "10": "Mindful Body Scan: Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.",
#     "11": "Listen to Calming Music or Nature Sounds: Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.",
#     "12": "Engage in a Hobby or Creative Activity: Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment.",
#     "13": "Connect with a Trusted Person: Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load.",
#     "14": "Gentle Stretching or Yoga: Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.",
#     "15": "Limit Exposure to Stress Triggers: If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks."
#   }
# }

# %%
type(temp)
# Out:
# str

# %%
solution_json=eval(temp)

# %%
type(solution_json)
# Out:
# dict

# %%
print(type(solution_json['solutions']))
# Out:
# <class 'dict'>

# %%
for i in range(len(solution_json['solutions'])):
    solution_json['solutions'][f'{i+1}']=solution_json['solutions'][f'{i+1}'].split(':')

# %%
dict_solution=dict()

# %%
for key,value in solution_json['solutions'].items():
    if key.isdigit():
        dict_solution[int(key)]=value

# %%
dict_solution
# Out:
# {1: ['Deep Diaphragmatic Breathing',
#   ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'],
#  2: ['Progressive Muscle Relaxation (PMR)',
#   ' Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.'],
#  3: ['Mindful Walking',
#   ' Take a 15-20 minute walk outdoors. Pay close attention to your senses',
#   ' the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.'],
#  4: ['Journaling for Career Worries',
#   ' Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.'],
#  5: ['Identify and Affirm Strengths',
#   ' Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.'],
#  6: ['Set Small, Achievable Goals',
#   ' Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.'],
#  7: ['Positive Self-Talk Practice',
#   " Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'"],
#  8: ['Gratitude Practice',
#   " Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook."],
#  9: ['Time Management Technique (e.g., Pomodoro)',
#   ' Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.'],
#  10: ['Mindful Body Scan',
#   ' Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.'],
#  11: ['Listen to Calming Music or Nature Sounds',
#   ' Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.'],
#  12: ['Engage in a Hobby or Creative Activity',
#   " Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment."],
#  13: ['Connect with a Trusted Person',
#   " Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load."],
#  14: ['Gentle Stretching or Yoga',
#   ' Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.'],
#  15: ['Limit Exposure to Stress Triggers',
#   ' If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks.']}

# %%
solution_json.pop('solutions')
# Out:
# {'1': ['Deep Diaphragmatic Breathing',
#   ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'],
#  '2': ['Progressive Muscle Relaxation (PMR)',
#   ' Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.'],
#  '3': ['Mindful Walking',
#   ' Take a 15-20 minute walk outdoors. Pay close attention to your senses',
#   ' the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.'],
#  '4': ['Journaling for Career Worries',
#   ' Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.'],
#  '5': ['Identify and Affirm Strengths',
#   ' Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.'],
#  '6': ['Set Small, Achievable Goals',
#   ' Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.'],
#  '7': ['Positive Self-Talk Practice',
#   " Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'"],
#  '8': ['Gratitude Practice',
#   " Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook."],
#  '9': ['Time Management Technique (e.g., Pomodoro)',
#   ' Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.'],
#  '10': ['Mindful Body Scan',
#   ' Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.'],
#  '11': ['Listen to Calming Music or Nature Sounds',
#   ' Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.'],
#  '12': ['Engage in a Hobby or Creative Activity',
#   " Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment."],
#  '13': ['Connect with a Trusted Person',
#   " Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load."],
#  '14': ['Gentle Stretching or Yoga',
#   ' Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.'],
#  '15': ['Limit Exposure to Stress Triggers',
#   ' If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks.']}

# %%
solution_json
# Out:
# {'main body': "It sounds like you're carrying a significant load right now, especially with the high career tension, and it's completely understandable to feel the effects on your anxiety, self-esteem, and confidence. Please know that it's a sign of strength to acknowledge these feelings. For the level of stress you're experiencing, it's highly recommended to consult with a doctor or a mental health professional. They can provide personalized guidance and support to help you navigate these challenges effectively. In the meantime, here are some supportive tasks you can try to help manage your stress, anxiety, and build your confidence, working alongside any professional advice you receive."}

# %%
solution_json['solutions']=dict_solution

# %%
solution_json
# Out:
# {'main body': "It sounds like you're carrying a significant load right now, especially with the high career tension, and it's completely understandable to feel the effects on your anxiety, self-esteem, and confidence. Please know that it's a sign of strength to acknowledge these feelings. For the level of stress you're experiencing, it's highly recommended to consult with a doctor or a mental health professional. They can provide personalized guidance and support to help you navigate these challenges effectively. In the meantime, here are some supportive tasks you can try to help manage your stress, anxiety, and build your confidence, working alongside any professional advice you receive.",
#  'solutions': {1: ['Deep Diaphragmatic Breathing',
#    ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'],
#   2: ['Progressive Muscle Relaxation (PMR)',
#    ' Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.'],
#   3: ['Mindful Walking',
#    ' Take a 15-20 minute walk outdoors. Pay close attention to your senses',
#    ' the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.'],
#   4: ['Journaling for Career Worries',
#    ' Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.'],
#   5: ['Identify and Affirm Strengths',
#    ' Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.'],
#   6: ['Set Small, Achievable Goals',
#    ' Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.'],
#   7: ['Positive Self-Talk Practice',
#    " Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'"],
#   8: ['Gratitude Practice',
#    " Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook."],
#   9: ['Time Management Technique (e.g., Pomodoro)',
#    ' Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.'],
#   10: ['Mindful Body Scan',
#    ' Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.'],
#   11: ['Listen to Calming Music or Nature Sounds',
#    ' Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.'],
#   12: ['Engage in a Hobby or Creative Activity',
#    " Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment."],
#   13: ['Connect with a Trusted Person',
#    " Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load."],
#   14: ['Gentle Stretching or Yoga',
#    ' Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.'],
#   15: ['Limit Exposure to Stress Triggers',
#    ' If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks.']}}

# %%
tasks=solution_json['solutions'].values()
for task in tasks:
    print(task[0])
# Out:
# Deep Diaphragmatic Breathing
# Progressive Muscle Relaxation (PMR)
# Mindful Walking
# Journaling for Career Worries
# Identify and Affirm Strengths
# Set Small, Achievable Goals
# Positive Self-Talk Practice
# Gratitude Practice
# Time Management Technique (e.g., Pomodoro)
# Mindful Body Scan
# Listen to Calming Music or Nature Sounds
# Engage in a Hobby or Creative Activity
# Connect with a Trusted Person
# Gentle Stretching or Yoga
# Limit Exposure to Stress Triggers

# %%
solution_json['solutions'][1][0]
# Out:
# 'Deep Diaphragmatic Breathing'

# %%
solution_json['solutions'][1][1]
# Out:
# ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'

# %%
list(solution_json.items())[0]
# Out:
# ('main body',
#  "It sounds like you're carrying a significant load right now, especially with the high career tension, and it's completely understandable to feel the effects on your anxiety, self-esteem, and confidence. Please know that it's a sign of strength to acknowledge these feelings. For the level of stress you're experiencing, it's highly recommended to consult with a doctor or a mental health professional. They can provide personalized guidance and support to help you navigate these challenges effectively. In the meantime, here are some supportive tasks you can try to help manage your stress, anxiety, and build your confidence, working alongside any professional advice you receive.")

# %%
import json
key=[1,2]
res=dict()
for item,value in solution_json['solutions'].items():
    if item in key:
        res[item]=value
print(res)
# Out:
# {1: ['Deep Diaphragmatic Breathing', ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'], 2: ['Progressive Muscle Relaxation (PMR)', ' Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.']}

# %%
# Out:
# mappingproxy({1: ['Deep Diaphragmatic Breathing',
#                ' Find a quiet space, sit or lie comfortably, and place one hand on your chest and the other on your belly. Inhale slowly through your nose, feeling your belly rise, then exhale slowly through pursed lips, feeling your belly fall. Repeat for 5-10 minutes to calm your nervous system and reduce anxiety.'],
#               2: ['Progressive Muscle Relaxation (PMR)',
#                ' Systematically tense and then relax different muscle groups in your body, starting from your toes and moving up to your head. Hold the tension for 5 seconds, then release for 30 seconds. This helps release physical tension often associated with stress and career pressure.'],
#               3: ['Mindful Walking',
#                ' Take a 15-20 minute walk outdoors. Pay close attention to your senses',
#                ' the feeling of your feet on the ground, the sounds around you, the sights, and the smells. This helps ground you in the present moment and can clear your mind from overwhelming thoughts.'],
#               4: ['Journaling for Career Worries',
#                ' Dedicate 10-15 minutes each day to write down all your career-related concerns, anxieties, and thoughts without judgment. Getting them out of your head and onto paper can help you gain perspective and feel more in control.'],
#               5: ['Identify and Affirm Strengths',
#                ' Make a list of at least 5-10 things you are good at, skills you possess, or positive qualities you have. These can be personal or professional. Read this list daily, especially when your confidence feels low, to remind yourself of your capabilities.'],
#               6: ['Set Small, Achievable Goals',
#                ' Break down larger tasks, especially career-related ones, into very small, manageable steps. Focus on completing just one small step at a time. Each completion will build your confidence and sense of accomplishment.'],
#               7: ['Positive Self-Talk Practice',
#                " Challenge negative thoughts about yourself or your abilities. When you catch yourself thinking something negative, reframe it into a more neutral or positive statement. For example, instead of 'I can't do this,' try 'I will try my best, and it's okay if it's not perfect.'"],
#               8: ['Gratitude Practice',
#                " Each day, list 3-5 things you are grateful for, no matter how small. This practice helps shift your focus from what's going wrong to what's going right, fostering a more positive outlook."],
#               9: ['Time Management Technique (e.g., Pomodoro)',
#                ' Use a technique like the Pomodoro method (25 minutes of focused work, 5-minute break) to tackle career tasks. This can help you feel more productive and less overwhelmed, reducing career tension.'],
#               10: ['Mindful Body Scan',
#                ' Lie down comfortably and bring your attention to different parts of your body, noticing any sensations without judgment. This helps you connect with your body and release any stored tension or discomfort.'],
#               11: ['Listen to Calming Music or Nature Sounds',
#                ' Create a playlist of soothing music or nature sounds (like ocean waves or gentle rain). Listen for 20-30 minutes to help reduce anxiety and promote relaxation.'],
#               12: ['Engage in a Hobby or Creative Activity',
#                " Spend time on something you enjoy, whether it's drawing, reading, gardening, or playing an instrument. This provides a healthy distraction and a sense of joy and accomplishment."],
#               13: ['Connect with a Trusted Person',
#                " Reach out to a friend, family member, or mentor you trust. Share how you're feeling without the pressure of finding a solution. Sometimes just talking can lighten your load."],
#               14: ['Gentle Stretching or Yoga',
#                ' Incorporate 10-15 minutes of gentle stretching or beginner yoga into your day. It helps release physical tension, improves flexibility, and can calm your mind.'],
#               15: ['Limit Exposure to Stress Triggers',
#                ' If possible, identify and temporarily reduce your exposure to specific situations or people that exacerbate your career tension or feelings of low confidence. This might involve setting boundaries or taking short breaks from certain tasks.']})
